# %% [markdown]
# # Imports

# %%
# !pip install pytabkit
# Out:
# Collecting pytabkit
#   Downloading pytabkit-1.7.3-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.12/dist-packages (from pytabkit) (2.0.2)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.12/dist-packages (from pytabkit) (2.2.2)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.12/dist-packages (from pytabkit) (5.9.5)
# Requirement already satisfied: pytorch-lightning>=2.0 in /usr/local/lib/python3.12/dist-packages (from pytabkit) (2.6.0)
# Requirement already satisfied: scikit-learn>=1.3 in /usr/local/lib/python3.12/dist-packages (from pytabkit) (1.6.1)
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.12/dist-packages (from pytabkit) (2.8.0+cu126)
# Requirement already satisfied: torchmetrics>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from pytabkit) (1.8.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->pytabkit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->pytabkit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->pytabkit) (2025.2)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning>=2.0->pytabkit) (4.67.1)
# Requirement already satisfied: PyYAML>5.4 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning>=2.0->pytabkit) (6.0.3)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=2.0->pytabkit) (2025.10.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning>=2.0->pytabkit) (26.0rc2)
# Requirement already satisfied: typing-extensions>4.5.0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning>=2.0->pytabkit) (4.15.0)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning>=2.0->pytabkit) (0.15.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3->pytabkit) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3->pytabkit) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3->pytabkit) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pytabkit) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pytabkit) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pytabkit) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pytabkit) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pytabkit) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pytabkit) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pytabkit) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pytabkit) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pytabkit) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pytabkit) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pytabkit) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pytabkit) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pytabkit) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pytabkit) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pytabkit) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pytabkit) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pytabkit) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pytabkit) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pytabkit) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pytabkit) (3.4.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=2.0->pytabkit) (3.13.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0->pytabkit) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0->pytabkit) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0->pytabkit) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0->pytabkit) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0->pytabkit) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0->pytabkit) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0->pytabkit) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0->pytabkit) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0->pytabkit) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0->pytabkit) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0->pytabkit) (3.11)
# Downloading pytabkit-1.7.3-py3-none-any.whl (364 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.0/364.0 kB 7.6 MB/s eta 0:00:00
# Installing collected packages: pytabkit
# Successfully installed pytabkit-1.7.3

# %%
import torch
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from pytabkit import RealMLP_TD_Classifier
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler, LabelEncoder

warnings.filterwarnings('ignore')

# %% [markdown]
# # Global Configuration

# %%
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
RANDOM_STATE = 42
N_FOLDS = 5
print(f"Using device: {DEVICE}")
# Out:
# Using device: cuda

# %%
import torch
print(f"GPU数量: {torch.cuda.device_count()}")
print(f"当前默认设备: {torch.cuda.current_device()}")
print(f"显卡名称: {torch.cuda.get_device_name(0)}")
# Out:
# GPU数量: 2
# 当前默认设备: 0
# 显卡名称: Tesla T4

# %% [markdown]
# # Data Loading and Preprocessing

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import KMeans

train = pd.read_csv("/kaggle/input/playground-series-s6e2/train.csv")
test = pd.read_csv("/kaggle/input/playground-series-s6e2/test.csv")
original = pd.read_csv("/kaggle/input/datasets/wangxintong111/heartdisease/Heart_Disease_Prediction.csv") 

# 1. 目标变量基础编码
le = LabelEncoder()
train['Heart Disease'] = le.fit_transform(train['Heart Disease'])
original['Heart Disease'] = le.fit_transform(original['Heart Disease'])

# ==========================================
# 🌟 策略 1：打上 is_real_data 标签
# ==========================================
features_to_compare = [c for c in train.columns if c not in ['id', 'Heart Disease']]
original_keys = original[features_to_compare].copy()
original_keys['is_real_data'] = 1

train = train.merge(original_keys, on=features_to_compare, how='left')
test = test.merge(original_keys, on=features_to_compare, how='left')
train['is_real_data'] = train['is_real_data'].fillna(0).astype(int)
test['is_real_data'] = test['is_real_data'].fillna(0).astype(int)

# ==========================================
# 🌟 加入 NEJM 全套特征
# ==========================================
def add_nejm_features_full(df):
    df_eng = df.copy()
    cols = df.columns
    bp_col = [c for c in cols if 'BP' in c or 'Pressure' in c][0]
    chol_col = [c for c in cols if 'Chol' in c][0]
    fbs_col = [c for c in cols if 'FBS' in c or 'Sugar' in c][0]
    sex_col = [c for c in cols if 'Sex' in c or 'gender' in c][0]
    
    df_eng['Risk_High_BP'] = (df_eng[bp_col] >= 140).astype(int)
    df_eng['Risk_High_Chol'] = (df_eng[chol_col] >= 240).astype(int)
    
    if df_eng[fbs_col].max() > 1:
        df_eng['Risk_Diabetes'] = (df_eng[fbs_col] > 120).astype(int)
    else:
        df_eng['Risk_Diabetes'] = df_eng[fbs_col].astype(int)

    df_eng['Risk_Burden_Score'] = df_eng['Risk_High_BP'] + df_eng['Risk_High_Chol'] + df_eng['Risk_Diabetes']
    df_eng['Age_Window_55_60'] = ((df_eng['Age'] >= 55) & (df_eng['Age'] < 60)).astype(int)
    df_eng['Critical_Age_Hypertension'] = df_eng['Age_Window_55_60'] * df_eng['Risk_High_BP']
    df_eng['Age_50_Plus'] = (df_eng['Age'] >= 50).astype(int)
    df_eng['Age50_Risk_Interaction'] = df_eng['Age_50_Plus'] * df_eng['Risk_Burden_Score']
    df_eng['Sex_Risk_Interaction'] = df_eng[sex_col].astype(int) * df_eng['Risk_Burden_Score']
    return df_eng

train = add_nejm_features_full(train)
test = add_nejm_features_full(test)
original = add_nejm_features_full(original)

# ==========================================
# 🌟 策略 2：计算原始数据的纯净统计特征
# ==========================================
base_features = [col for col in train.columns if col not in ['Heart Disease', 'id']] 

def add_engineered_features(df):
    df_temp = df.copy()
    for col in base_features: 
        if col in original.columns:
            stats = original.groupby(col)['Heart Disease'].agg(['mean', 'median', 'std', 'skew', 'count']).reset_index()
            stats.columns = [col] + [f"orig_{col}_{s}" for s in ['mean', 'median', 'std', 'skew', 'count']]
            df_temp = df_temp.merge(stats, on=col, how='left') 
            fill_values = {
                f"orig_{col}_mean": original['Heart Disease'].mean(),
                f"orig_{col}_median": original['Heart Disease'].median(),
                f"orig_{col}_std": 0, f"orig_{col}_skew": 0, f"orig_{col}_count": 0
            }
            df_temp = df_temp.fillna(value=fill_values)
    return df_temp

train = add_engineered_features(train)
test = add_engineered_features(test) 

# ==========================================
# 🌟 [新增] KNN 距离与 KMeans 聚类特征
# ==========================================
# 选取常见的连续数值列（确保列名与你的数据集匹配）
num_cols = [c for c in ['Age', 'BP', 'Cholesterol', 'Max HR', 'Oldpeak'] if c in train.columns]

if len(num_cols) > 0:
    scaler = StandardScaler()
    orig_scaled = scaler.fit_transform(original[num_cols])
    train_scaled = scaler.transform(train[num_cols])
    test_scaled = scaler.transform(test[num_cols])

    # A: KNN 距离
    nn = NearestNeighbors(n_neighbors=1, algorithm='kd_tree')
    nn.fit(orig_scaled)
    train['dist_to_real_patient'], _ = nn.kneighbors(train_scaled)
    test['dist_to_real_patient'], _ = nn.kneighbors(test_scaled)
    original['dist_to_real_patient'] = 0.0

    # B: KMeans 真实画像聚类
    kmeans = KMeans(n_clusters=5, random_state=42, n_init=10)
    kmeans.fit(orig_scaled)
    train['Real_Patient_Cluster'] = kmeans.predict(train_scaled)
    test['Real_Patient_Cluster'] = kmeans.predict(test_scaled)
    original['Real_Patient_Cluster'] = kmeans.predict(orig_scaled)

# ==========================================
# 🌟 直接拼接原始数据 (Oversampling)
# ==========================================
original_for_concat = original.drop(columns=['id'], errors='ignore')
train = pd.concat([train, original_for_concat], axis=0).reset_index(drop=True)

X = train.drop(['id', 'Heart Disease'], axis=1)
y = train['Heart Disease']
X_test = test.drop(['id'], axis=1)

print(f"✅ Preprocessing Done! Train shape: {X.shape}, Test shape: {X_test.shape}")
# Out:
# ✅ Preprocessing Done! Train shape: (630270, 135), Test shape: (270000, 135)

# %% [markdown]
# # Data Quality Check (Missing & Duplicates)

# %%
def check_data_quality(df, name="Dataset"):
    print(f"--- Data Quality: {name} ---")
    print(f"Total Rows: {len(df)}")

    cols_to_check = [c for c in df.columns if c != 'id']
    dupes = df.duplicated(subset=cols_to_check).sum()

    nan_counts = df.isnull().sum()
    total_nans = nan_counts.sum()
    
    print(f"Duplicate Rows (excl. ID): {dupes}")
    print(f"Total NaN values: {total_nans}")
    if total_nans > 0:
        print("\nColumns with NaNs:")
        print(nan_counts[nan_counts > 0])
    print("-" * 30)

check_data_quality(train, "Train")
check_data_quality(test, "Test")
# Out:
# --- Data Quality: Train ---
# Total Rows: 630270
# Duplicate Rows (excl. ID): 0
# Total NaN values: 30240
#
# Columns with NaNs:
# id                                  270
# is_real_data                        270
# orig_Age_mean                       270
# orig_Age_median                     270
# orig_Age_std                        270
#                                    ...
# orig_Sex_Risk_Interaction_mean      270
# orig_Sex_Risk_Interaction_median    270
# orig_Sex_Risk_Interaction_std       270
# orig_Sex_Risk_Interaction_skew      270
# orig_Sex_Risk_Interaction_count     270
# Length: 112, dtype: int64
# ------------------------------
# --- Data Quality: Test ---
# Total Rows: 270000
# Duplicate Rows (excl. ID): 0
# Total NaN values: 0
# ------------------------------

# %% [markdown]
# # Feature Uniqueness & Cardinality

# %%
def analyze_uniqueness(df):
    unique_stats = []
    for col in df.columns:
        if col == 'id': continue
        
        n_unique = df[col].nunique()
        dtype = df[col].dtype

        category_guess = "Categorical/Ordinal" if n_unique < 25 else "Continuous"
        
        unique_stats.append({
            'Feature': col,
            'Unique Values': n_unique,
            'Data Type': dtype,
            'Heuristic Type': category_guess
        })
    
    return pd.DataFrame(unique_stats).sort_values(by='Unique Values')

uniqueness_df = analyze_uniqueness(train)
print(uniqueness_df)
# Out:
#                        Feature  Unique Values Data Type       Heuristic Type
# 14                is_real_data              1   float64  Categorical/Ordinal
# 50    orig_FBS over 120_median              1   float64  Categorical/Ordinal
# 100  orig_Risk_Diabetes_median              1   float64  Categorical/Ordinal
# 8              Exercise angina              2     int64  Categorical/Ordinal
# 15                Risk_High_BP              2     int64  Categorical/Ordinal
# ..                         ...            ...       ...                  ...
# 9                ST depression             66   float64           Continuous
# 3                           BP             66     int64           Continuous
# 7                       Max HR             93     int64           Continuous
# 4                  Cholesterol            153     int64           Continuous
# 134       dist_to_real_patient         104965   float64           Continuous
#
# [136 rows x 4 columns]

# %% [markdown]
# # Visualize Top Skewed Features

# %%
numeric_cols = X.select_dtypes(include=[np.number]).columns.tolist()

skew_series = X[numeric_cols].skew().abs().sort_values(ascending=False)
top_skewed_features = skew_series.head(6).index.tolist()

print("Top 6 Most Skewed Features (Absolute Values):")
print(X[top_skewed_features].skew())

plt.figure(figsize=(16, 10))
for i, col in enumerate(top_skewed_features):
    plt.subplot(2, 3, i + 1) 
    sns.histplot(X[col].sample(min(10000, len(X))), kde=True, color='teal', bins=30)
    plt.title(f"Feature: {col}\nSkewness: {X[col].skew():.2f}")
    plt.xlabel("")
    plt.ylabel("Frequency")

plt.tight_layout()
plt.savefig('skewed_distributions.png')
# Out:
# Top 6 Most Skewed Features (Absolute Values):
# orig_EKG results_count                -15.613416
# orig_EKG results_std                    6.747575
# orig_Slope of ST_count                 -5.657311
# orig_Thallium_std                       4.472673
# orig_BP_std                            -4.174508
# orig_Critical_Age_Hypertension_skew    -3.385113
# dtype: float64

# %% [markdown]
# # Cross-Validation & Training

# %%
# %%time
import torch
import gc
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
from joblib import Parallel, delayed

# 1. 环境检查
n_gpus = torch.cuda.device_count()
print(f"🟢 Detected {n_gpus} GPUs. Mode: {'Parallel' if n_gpus > 1 else 'Sequential'}")

# 2. 基础参数
param_grid = {
    'random_state': 42,
    'verbosity': 1, 
    'n_epochs': 100,
    'batch_size': 512, 
    'n_ens': 8, 
    'use_early_stopping': True,
    'early_stopping_additive_patience': 20,
    'early_stopping_multiplicative_patience': 1,
    'act': "mish",
    'embedding_size': 8,
    'first_layer_lr_factor': 0.5962121993798933,
    'hidden_sizes': "rectangular",
    'hidden_width': 384,
    'lr': 0.04, 
    'ls_eps': 0.011498317194338772,
    'ls_eps_sched': "coslog4",
    'max_one_hot_cat_size': 18,
    'n_hidden_layers': 4, 
    'p_drop': 0.07301419697186451,
    'p_drop_sched': "flat_cos",
    'plr_hidden_1': 16, 
    'plr_hidden_2': 8,
    'plr_lr_factor': 0.1151437622270563,
    'plr_sigma': 2.3316811282666916,
    'scale_lr_factor': 2.244801835541429,
    'sq_mom': 1.0 - 0.011834054955582318,
    'wd': 0.02369230879235962,
} 

# 3. 数据预处理
X = X.reset_index(drop=True)
y = y.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)

# ==========================================
# 🌟 关键防御：对连续的浮点数特征进行“分箱” (Binning)
# ==========================================
# 自动找出所有的原始连续特征、Target Encoding的统计特征、以及 KNN 距离特征
continuous_cols = [c for c in X.columns if ('orig_' in c) or ('dist_to' in c) or (c in ['Age', 'Resting BP', 'Cholesterol', 'Max HR', 'Oldpeak', 'BP', 'MaxHR'])]

# 将这些连续变量切分成最多 50 个离散的等级 (箱子)
# 这样不仅保留了数值的相对大小关系，还严格限制了 Category 的数量，防止 GPU 内存爆炸
for col in continuous_cols:
    if col in X.columns:
        # 拼接 train 和 test 一起分箱，保证箱子的边界完全一致
        combined = pd.concat([X[col], X_test[col]], axis=0)
        # qcut 按分位数切分，保证每个箱子里的样本数差不多
        # duplicates='drop' 防止大量相同数值（如距离0）导致报错
        combined_binned = pd.qcut(combined, q=50, labels=False, duplicates='drop')
        
        # 切分回去赋值
        X[col] = combined_binned.iloc[:len(X)].values
        X_test[col] = combined_binned.iloc[len(X):].values

print(f"✅ 已将 {len([c for c in continuous_cols if c in X.columns])} 个连续特征安全分箱。")

# ==========================================
# 🌟 恢复全量 Category 转换逻辑
# ==========================================
# 现在所有的特征（包括被分箱的连续特征）都只有少量的独特值了，可以安全地全量转类别
for col in X.columns:
    X[col] = X[col].astype(str).astype('category')
    X_test[col] = X_test[col].astype(str).astype('category') 

print("✅ 所有特征均已转换为 Category 格式，准备送入 RealMLP！")

skf = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=RANDOM_STATE)

# 4. 定义单个 Fold 的训练函数
def train_single_fold(fold, train_idx, val_idx):
    device_id = fold % n_gpus
    device = f'cuda:{device_id}'
    
    print(f"🚀 Fold {fold + 1} started on {device}...")
    
    fold_params = param_grid.copy()
    fold_params['device'] = device
    
    X_tr, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_tr, y_val = y.iloc[train_idx], y.iloc[val_idx]
    
    model = RealMLP_TD_Classifier(**fold_params) 
    model.fit(X_tr, y_tr.values, X_val, y_val.values) 
    
    val_probs = model.predict_proba(X_val)[:, 1]
    test_probs = model.predict_proba(X_test)[:, 1]
    
    score = roc_auc_score(y_val, val_probs)
    print(f"✅ Fold {fold + 1} finished on {device}. AUC: {score:.5f}")
    
    del model, X_tr, X_val, y_tr, y_val
    gc.collect()
    if device.startswith('cuda'):
        try:
            torch.cuda.set_device(device)
            torch.cuda.empty_cache()
        except:
            pass
            
    return val_idx, val_probs, test_probs, score

# 5. 并行执行
results = Parallel(n_jobs=n_gpus, backend="loky")(
    delayed(train_single_fold)(fold, train_idx, val_idx) 
    for fold, (train_idx, val_idx) in enumerate(skf.split(X, y))
)

# 6. 汇总结果
oof_preds = np.zeros(len(X))
test_preds = np.zeros(len(X_test))
fold_scores = []

for val_idx, val_probs, fold_test_probs, score in results:
    oof_preds[val_idx] = val_probs
    test_preds += fold_test_probs / N_FOLDS
    fold_scores.append(score)

print(f"\n" + "="*40)
print(f"Mean AUC: {np.mean(fold_scores):.5f}")
print("="*40)
# Out:
# 🟢 Detected 2 GPUs. Mode: Parallel
# ✅ 已将 115 个连续特征安全分箱。
# ✅ 所有特征均已转换为 Category 格式，准备送入 RealMLP！
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 🚀 Fold 1 started on cuda:0...
# Columns classified as continuous: []
# Columns classified as categorical: ['Age', 'Sex', 'Chest pain type', 'BP', 'Cholesterol', 'FBS over 120', 'EKG results', 'Max HR', 'Exercise angina', 'ST depression', 'Slope of ST', 'Number of vessels fluro', 'Thallium', 'is_real_data', 'Risk_High_BP', 'Risk_High_Chol', 'Risk_Diabetes', 'Risk_Burden_Score', 'Age_Window_55_60', 'Critical_Age_Hypertension', 'Age_50_Plus', 'Age50_Risk_Interaction', 'Sex_Risk_Interaction', 'orig_Age_mean', 'orig_Age_median', 'orig_Age_std', 'orig_Age_skew', 'orig_Age_count', 'orig_Sex_mean', 'orig_Sex_median', 'orig_Sex_std', 'orig_Sex_skew', 'orig_Sex_count', 'orig_Chest pain type_mean', 'orig_Chest pain type_median', 'orig_Chest pain type_std', 'orig_Chest pain type_skew', 'orig_Chest pain type_count', 'orig_BP_mean', 'orig_BP_median', 'orig_BP_std', 'orig_BP_skew', 'orig_BP_count', 'orig_Cholesterol_mean', 'orig_Cholesterol_median', 'orig_Cholesterol_std', 'orig_Cholesterol_skew', 'orig_Cholesterol_count', 'orig_FBS over 120_mean', 'orig_FBS over 120_median', 'orig_FBS over 120_std', 'orig_FBS over 120_skew', 'orig_FBS over 120_count', 'orig_EKG results_mean', 'orig_EKG results_median', 'orig_EKG results_std', 'orig_EKG results_skew', 'orig_EKG results_count', 'orig_Max HR_mean', 'orig_Max HR_median', 'orig_Max HR_std', 'orig_Max HR_skew', 'orig_Max HR_count', 'orig_Exercise angina_mean', 'orig_Exercise angina_median', 'orig_Exercise angina_std', 'orig_Exercise angina_skew', 'orig_Exercise angina_count', 'orig_ST depression_mean', 'orig_ST depression_median', 'orig_ST depression_std', 'orig_ST depression_skew', 'orig_ST depression_count', 'orig_Slope of ST_mean', 'orig_Slope of ST_median', 'orig_Slope of ST_std', 'orig_Slope of ST_skew', 'orig_Slope of ST_count', 'orig_Number of vessels fluro_mean', 'orig_Number of vessels fluro_median', 'orig_Number of vessels fluro_std', 'orig_Number of vessels fluro_skew', 'orig_Number of vessels fluro_count', 'orig_Thallium_mean', 'orig_Thallium_median', 'orig_Thallium_std', 'orig_Thallium_skew', 'orig_Thallium_count', 'orig_Risk_High_BP_mean', 'orig_Risk_High_BP_median', 'orig_Risk_High_BP_std', 'orig_Risk_High_BP_skew', 'orig_Risk_High_BP_count', 'orig_Risk_High_Chol_mean', 'orig_Risk_High_Chol_median', 'orig_Risk_High_Chol_std', 'orig_Risk_High_Chol_skew', 'orig_Risk_High_Chol_count', 'orig_Risk_Diabetes_mean', 'orig_Risk_Diabetes_median', 'orig_Risk_Diabetes_std', 'orig_Risk_Diabetes_skew', 'orig_Risk_Diabetes_count', 'orig_Risk_Burden_Score_mean', 'orig_Risk_Burden_Score_median', 'orig_Risk_Burden_Score_std', 'orig_Risk_Burden_Score_skew', 'orig_Risk_Burden_Score_count', 'orig_Age_Window_55_60_mean', 'orig_Age_Window_55_60_median', 'orig_Age_Window_55_60_std', 'orig_Age_Window_55_60_skew', 'orig_Age_Window_55_60_count', 'orig_Critical_Age_Hypertension_mean', 'orig_Critical_Age_Hypertension_median', 'orig_Critical_Age_Hypertension_std', 'orig_Critical_Age_Hypertension_skew', 'orig_Critical_Age_Hypertension_count', 'orig_Age_50_Plus_mean', 'orig_Age_50_Plus_median', 'orig_Age_50_Plus_std', 'orig_Age_50_Plus_skew', 'orig_Age_50_Plus_count', 'orig_Age50_Risk_Interaction_mean', 'orig_Age50_Risk_Interaction_median', 'orig_Age50_Risk_Interaction_std', 'orig_Age50_Risk_Interaction_skew', 'orig_Age50_Risk_Interaction_count', 'orig_Sex_Risk_Interaction_mean', 'orig_Sex_Risk_Interaction_median', 'orig_Sex_Risk_Interaction_std', 'orig_Sex_Risk_Interaction_skew', 'orig_Sex_Risk_Interaction_count', 'dist_to_real_patient', 'Real_Patient_Cluster']
# ✅ Fold 1 finished on cuda:0. AUC: 0.95568
# 🚀 Fold 3 started on cuda:0...
# Columns classified as continuous: []
# Columns classified as categorical: ['Age', 'Sex', 'Chest pain type', 'BP', 'Cholesterol', 'FBS over 120', 'EKG results', 'Max HR', 'Exercise angina', 'ST depression', 'Slope of ST', 'Number of vessels fluro', 'Thallium', 'is_real_data', 'Risk_High_BP', 'Risk_High_Chol', 'Risk_Diabetes', 'Risk_Burden_Score', 'Age_Window_55_60', 'Critical_Age_Hypertension', 'Age_50_Plus', 'Age50_Risk_Interaction', 'Sex_Risk_Interaction', 'orig_Age_mean', 'orig_Age_median', 'orig_Age_std', 'orig_Age_skew', 'orig_Age_count', 'orig_Sex_mean', 'orig_Sex_median', 'orig_Sex_std', 'orig_Sex_skew', 'orig_Sex_count', 'orig_Chest pain type_mean', 'orig_Chest pain type_median', 'orig_Chest pain type_std', 'orig_Chest pain type_skew', 'orig_Chest pain type_count', 'orig_BP_mean', 'orig_BP_median', 'orig_BP_std', 'orig_BP_skew', 'orig_BP_count', 'orig_Cholesterol_mean', 'orig_Cholesterol_median', 'orig_Cholesterol_std', 'orig_Cholesterol_skew', 'orig_Cholesterol_count', 'orig_FBS over 120_mean', 'orig_FBS over 120_median', 'orig_FBS over 120_std', 'orig_FBS over 120_skew', 'orig_FBS over 120_count', 'orig_EKG results_mean', 'orig_EKG results_median', 'orig_EKG results_std', 'orig_EKG results_skew', 'orig_EKG results_count', 'orig_Max HR_mean', 'orig_Max HR_median', 'orig_Max HR_std', 'orig_Max HR_skew', 'orig_Max HR_count', 'orig_Exercise angina_mean', 'orig_Exercise angina_median', 'orig_Exercise angina_std', 'orig_Exercise angina_skew', 'orig_Exercise angina_count', 'orig_ST depression_mean', 'orig_ST depression_median', 'orig_ST depression_std', 'orig_ST depression_skew', 'orig_ST depression_count', 'orig_Slope of ST_mean', 'orig_Slope of ST_median', 'orig_Slope of ST_std', 'orig_Slope of ST_skew', 'orig_Slope of ST_count', 'orig_Number of vessels fluro_mean', 'orig_Number of vessels fluro_median', 'orig_Number of vessels fluro_std', 'orig_Number of vessels fluro_skew', 'orig_Number of vessels fluro_count', 'orig_Thallium_mean', 'orig_Thallium_median', 'orig_Thallium_std', 'orig_Thallium_skew', 'orig_Thallium_count', 'orig_Risk_High_BP_mean', 'orig_Risk_High_BP_median', 'orig_Risk_High_BP_std', 'orig_Risk_High_BP_skew', 'orig_Risk_High_BP_count', 'orig_Risk_High_Chol_mean', 'orig_Risk_High_Chol_median', 'orig_Risk_High_Chol_std', 'orig_Risk_High_Chol_skew', 'orig_Risk_High_Chol_count', 'orig_Risk_Diabetes_mean', 'orig_Risk_Diabetes_median', 'orig_Risk_Diabetes_std', 'orig_Risk_Diabetes_skew', 'orig_Risk_Diabetes_count', 'orig_Risk_Burden_Score_mean', 'orig_Risk_Burden_Score_median', 'orig_Risk_Burden_Score_std', 'orig_Risk_Burden_Score_skew', 'orig_Risk_Burden_Score_count', 'orig_Age_Window_55_60_mean', 'orig_Age_Window_55_60_median', 'orig_Age_Window_55_60_std', 'orig_Age_Window_55_60_skew', 'orig_Age_Window_55_60_count', 'orig_Critical_Age_Hypertension_mean', 'orig_Critical_Age_Hypertension_median', 'orig_Critical_Age_Hypertension_std', 'orig_Critical_Age_Hypertension_skew', 'orig_Critical_Age_Hypertension_count', 'orig_Age_50_Plus_mean', 'orig_Age_50_Plus_median', 'orig_Age_50_Plus_std', 'orig_Age_50_Plus_skew', 'orig_Age_50_Plus_count', 'orig_Age50_Risk_Interaction_mean', 'orig_Age50_Risk_Interaction_median', 'orig_Age50_Risk_Interaction_std', 'orig_Age50_Risk_Interaction_skew', 'orig_Age50_Risk_Interaction_count', 'orig_Sex_Risk_Interaction_mean', 'orig_Sex_Risk_Interaction_median', 'orig_Sex_Risk_Interaction_std', 'orig_Sex_Risk_Interaction_skew', 'orig_Sex_Risk_Interaction_count', 'dist_to_real_patient', 'Real_Patient_Cluster']
# ✅ Fold 3 finished on cuda:0. AUC: 0.95439
# 🚀 Fold 5 started on cuda:0...
# Columns classified as continuous: []
# Columns classified as categorical: ['Age', 'Sex', 'Chest pain type', 'BP', 'Cholesterol', 'FBS over 120', 'EKG results', 'Max HR', 'Exercise angina', 'ST depression', 'Slope of ST', 'Number of vessels fluro', 'Thallium', 'is_real_data', 'Risk_High_BP', 'Risk_High_Chol', 'Risk_Diabetes', 'Risk_Burden_Score', 'Age_Window_55_60', 'Critical_Age_Hypertension', 'Age_50_Plus', 'Age50_Risk_Interaction', 'Sex_Risk_Interaction', 'orig_Age_mean', 'orig_Age_median', 'orig_Age_std', 'orig_Age_skew', 'orig_Age_count', 'orig_Sex_mean', 'orig_Sex_median', 'orig_Sex_std', 'orig_Sex_skew', 'orig_Sex_count', 'orig_Chest pain type_mean', 'orig_Chest pain type_median', 'orig_Chest pain type_std', 'orig_Chest pain type_skew', 'orig_Chest pain type_count', 'orig_BP_mean', 'orig_BP_median', 'orig_BP_std', 'orig_BP_skew', 'orig_BP_count', 'orig_Cholesterol_mean', 'orig_Cholesterol_median', 'orig_Cholesterol_std', 'orig_Cholesterol_skew', 'orig_Cholesterol_count', 'orig_FBS over 120_mean', 'orig_FBS over 120_median', 'orig_FBS over 120_std', 'orig_FBS over 120_skew', 'orig_FBS over 120_count', 'orig_EKG results_mean', 'orig_EKG results_median', 'orig_EKG results_std', 'orig_EKG results_skew', 'orig_EKG results_count', 'orig_Max HR_mean', 'orig_Max HR_median', 'orig_Max HR_std', 'orig_Max HR_skew', 'orig_Max HR_count', 'orig_Exercise angina_mean', 'orig_Exercise angina_median', 'orig_Exercise angina_std', 'orig_Exercise angina_skew', 'orig_Exercise angina_count', 'orig_ST depression_mean', 'orig_ST depression_median', 'orig_ST depression_std', 'orig_ST depression_skew', 'orig_ST depression_count', 'orig_Slope of ST_mean', 'orig_Slope of ST_median', 'orig_Slope of ST_std', 'orig_Slope of ST_skew', 'orig_Slope of ST_count', 'orig_Number of vessels fluro_mean', 'orig_Number of vessels fluro_median', 'orig_Number of vessels fluro_std', 'orig_Number of vessels fluro_skew', 'orig_Number of vessels fluro_count', 'orig_Thallium_mean', 'orig_Thallium_median', 'orig_Thallium_std', 'orig_Thallium_skew', 'orig_Thallium_count', 'orig_Risk_High_BP_mean', 'orig_Risk_High_BP_median', 'orig_Risk_High_BP_std', 'orig_Risk_High_BP_skew', 'orig_Risk_High_BP_count', 'orig_Risk_High_Chol_mean', 'orig_Risk_High_Chol_median', 'orig_Risk_High_Chol_std', 'orig_Risk_High_Chol_skew', 'orig_Risk_High_Chol_count', 'orig_Risk_Diabetes_mean', 'orig_Risk_Diabetes_median', 'orig_Risk_Diabetes_std', 'orig_Risk_Diabetes_skew', 'orig_Risk_Diabetes_count', 'orig_Risk_Burden_Score_mean', 'orig_Risk_Burden_Score_median', 'orig_Risk_Burden_Score_std', 'orig_Risk_Burden_Score_skew', 'orig_Risk_Burden_Score_count', 'orig_Age_Window_55_60_mean', 'orig_Age_Window_55_60_median', 'orig_Age_Window_55_60_std', 'orig_Age_Window_55_60_skew', 'orig_Age_Window_55_60_count', 'orig_Critical_Age_Hypertension_mean', 'orig_Critical_Age_Hypertension_median', 'orig_Critical_Age_Hypertension_std', 'orig_Critical_Age_Hypertension_skew', 'orig_Critical_Age_Hypertension_count', 'orig_Age_50_Plus_mean', 'orig_Age_50_Plus_median', 'orig_Age_50_Plus_std', 'orig_Age_50_Plus_skew', 'orig_Age_50_Plus_count', 'orig_Age50_Risk_Interaction_mean', 'orig_Age50_Risk_Interaction_median', 'orig_Age50_Risk_Interaction_std', 'orig_Age50_Risk_Interaction_skew', 'orig_Age50_Risk_Interaction_count', 'orig_Sex_Risk_Interaction_mean', 'orig_Sex_Risk_Interaction_median', 'orig_Sex_Risk_Interaction_std', 'orig_Sex_Risk_Interaction_skew', 'orig_Sex_Risk_Interaction_count', 'dist_to_real_patient', 'Real_Patient_Cluster']
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# 🚀 Fold 2 started on cuda:1...
# Columns classified as continuous: []
# Columns classified as categorical: ['Age', 'Sex', 'Chest pain type', 'BP', 'Cholesterol', 'FBS over 120', 'EKG results', 'Max HR', 'Exercise angina', 'ST depression', 'Slope of ST', 'Number of vessels fluro', 'Thallium', 'is_real_data', 'Risk_High_BP', 'Risk_High_Chol', 'Risk_Diabetes', 'Risk_Burden_Score', 'Age_Window_55_60', 'Critical_Age_Hypertension', 'Age_50_Plus', 'Age50_Risk_Interaction', 'Sex_Risk_Interaction', 'orig_Age_mean', 'orig_Age_median', 'orig_Age_std', 'orig_Age_skew', 'orig_Age_count', 'orig_Sex_mean', 'orig_Sex_median', 'orig_Sex_std', 'orig_Sex_skew', 'orig_Sex_count', 'orig_Chest pain type_mean', 'orig_Chest pain type_median', 'orig_Chest pain type_std', 'orig_Chest pain type_skew', 'orig_Chest pain type_count', 'orig_BP_mean', 'orig_BP_median', 'orig_BP_std', 'orig_BP_skew', 'orig_BP_count', 'orig_Cholesterol_mean', 'orig_Cholesterol_median', 'orig_Cholesterol_std', 'orig_Cholesterol_skew', 'orig_Cholesterol_count', 'orig_FBS over 120_mean', 'orig_FBS over 120_median', 'orig_FBS over 120_std', 'orig_FBS over 120_skew', 'orig_FBS over 120_count', 'orig_EKG results_mean', 'orig_EKG results_median', 'orig_EKG results_std', 'orig_EKG results_skew', 'orig_EKG results_count', 'orig_Max HR_mean', 'orig_Max HR_median', 'orig_Max HR_std', 'orig_Max HR_skew', 'orig_Max HR_count', 'orig_Exercise angina_mean', 'orig_Exercise angina_median', 'orig_Exercise angina_std', 'orig_Exercise angina_skew', 'orig_Exercise angina_count', 'orig_ST depression_mean', 'orig_ST depression_median', 'orig_ST depression_std', 'orig_ST depression_skew', 'orig_ST depression_count', 'orig_Slope of ST_mean', 'orig_Slope of ST_median', 'orig_Slope of ST_std', 'orig_Slope of ST_skew', 'orig_Slope of ST_count', 'orig_Number of vessels fluro_mean', 'orig_Number of vessels fluro_median', 'orig_Number of vessels fluro_std', 'orig_Number of vessels fluro_skew', 'orig_Number of vessels fluro_count', 'orig_Thallium_mean', 'orig_Thallium_median', 'orig_Thallium_std', 'orig_Thallium_skew', 'orig_Thallium_count', 'orig_Risk_High_BP_mean', 'orig_Risk_High_BP_median', 'orig_Risk_High_BP_std', 'orig_Risk_High_BP_skew', 'orig_Risk_High_BP_count', 'orig_Risk_High_Chol_mean', 'orig_Risk_High_Chol_median', 'orig_Risk_High_Chol_std', 'orig_Risk_High_Chol_skew', 'orig_Risk_High_Chol_count', 'orig_Risk_Diabetes_mean', 'orig_Risk_Diabetes_median', 'orig_Risk_Diabetes_std', 'orig_Risk_Diabetes_skew', 'orig_Risk_Diabetes_count', 'orig_Risk_Burden_Score_mean', 'orig_Risk_Burden_Score_median', 'orig_Risk_Burden_Score_std', 'orig_Risk_Burden_Score_skew', 'orig_Risk_Burden_Score_count', 'orig_Age_Window_55_60_mean', 'orig_Age_Window_55_60_median', 'orig_Age_Window_55_60_std', 'orig_Age_Window_55_60_skew', 'orig_Age_Window_55_60_count', 'orig_Critical_Age_Hypertension_mean', 'orig_Critical_Age_Hypertension_median', 'orig_Critical_Age_Hypertension_std', 'orig_Critical_Age_Hypertension_skew', 'orig_Critical_Age_Hypertension_count', 'orig_Age_50_Plus_mean', 'orig_Age_50_Plus_median', 'orig_Age_50_Plus_std', 'orig_Age_50_Plus_skew', 'orig_Age_50_Plus_count', 'orig_Age50_Risk_Interaction_mean', 'orig_Age50_Risk_Interaction_median', 'orig_Age50_Risk_Interaction_std', 'orig_Age50_Risk_Interaction_skew', 'orig_Age50_Risk_Interaction_count', 'orig_Sex_Risk_Interaction_mean', 'orig_Sex_Risk_Interaction_median', 'orig_Sex_Risk_Interaction_std', 'orig_Sex_Risk_Interaction_skew', 'orig_Sex_Risk_Interaction_count', 'dist_to_real_patient', 'Real_Patient_Cluster']
# ✅ Fold 2 finished on cuda:1. AUC: 0.95583
# 🚀 Fold 4 started on cuda:1...
# Columns classified as continuous: []
# Columns classified as categorical: ['Age', 'Sex', 'Chest pain type', 'BP', 'Cholesterol', 'FBS over 120', 'EKG results', 'Max HR', 'Exercise angina', 'ST depression', 'Slope of ST', 'Number of vessels fluro', 'Thallium', 'is_real_data', 'Risk_High_BP', 'Risk_High_Chol', 'Risk_Diabetes', 'Risk_Burden_Score', 'Age_Window_55_60', 'Critical_Age_Hypertension', 'Age_50_Plus', 'Age50_Risk_Interaction', 'Sex_Risk_Interaction', 'orig_Age_mean', 'orig_Age_median', 'orig_Age_std', 'orig_Age_skew', 'orig_Age_count', 'orig_Sex_mean', 'orig_Sex_median', 'orig_Sex_std', 'orig_Sex_skew', 'orig_Sex_count', 'orig_Chest pain type_mean', 'orig_Chest pain type_median', 'orig_Chest pain type_std', 'orig_Chest pain type_skew', 'orig_Chest pain type_count', 'orig_BP_mean', 'orig_BP_median', 'orig_BP_std', 'orig_BP_skew', 'orig_BP_count', 'orig_Cholesterol_mean', 'orig_Cholesterol_median', 'orig_Cholesterol_std', 'orig_Cholesterol_skew', 'orig_Cholesterol_count', 'orig_FBS over 120_mean', 'orig_FBS over 120_median', 'orig_FBS over 120_std', 'orig_FBS over 120_skew', 'orig_FBS over 120_count', 'orig_EKG results_mean', 'orig_EKG results_median', 'orig_EKG results_std', 'orig_EKG results_skew', 'orig_EKG results_count', 'orig_Max HR_mean', 'orig_Max HR_median', 'orig_Max HR_std', 'orig_Max HR_skew', 'orig_Max HR_count', 'orig_Exercise angina_mean', 'orig_Exercise angina_median', 'orig_Exercise angina_std', 'orig_Exercise angina_skew', 'orig_Exercise angina_count', 'orig_ST depression_mean', 'orig_ST depression_median', 'orig_ST depression_std', 'orig_ST depression_skew', 'orig_ST depression_count', 'orig_Slope of ST_mean', 'orig_Slope of ST_median', 'orig_Slope of ST_std', 'orig_Slope of ST_skew', 'orig_Slope of ST_count', 'orig_Number of vessels fluro_mean', 'orig_Number of vessels fluro_median', 'orig_Number of vessels fluro_std', 'orig_Number of vessels fluro_skew', 'orig_Number of vessels fluro_count', 'orig_Thallium_mean', 'orig_Thallium_median', 'orig_Thallium_std', 'orig_Thallium_skew', 'orig_Thallium_count', 'orig_Risk_High_BP_mean', 'orig_Risk_High_BP_median', 'orig_Risk_High_BP_std', 'orig_Risk_High_BP_skew', 'orig_Risk_High_BP_count', 'orig_Risk_High_Chol_mean', 'orig_Risk_High_Chol_median', 'orig_Risk_High_Chol_std', 'orig_Risk_High_Chol_skew', 'orig_Risk_High_Chol_count', 'orig_Risk_Diabetes_mean', 'orig_Risk_Diabetes_median', 'orig_Risk_Diabetes_std', 'orig_Risk_Diabetes_skew', 'orig_Risk_Diabetes_count', 'orig_Risk_Burden_Score_mean', 'orig_Risk_Burden_Score_median', 'orig_Risk_Burden_Score_std', 'orig_Risk_Burden_Score_skew', 'orig_Risk_Burden_Score_count', 'orig_Age_Window_55_60_mean', 'orig_Age_Window_55_60_median', 'orig_Age_Window_55_60_std', 'orig_Age_Window_55_60_skew', 'orig_Age_Window_55_60_count', 'orig_Critical_Age_Hypertension_mean', 'orig_Critical_Age_Hypertension_median', 'orig_Critical_Age_Hypertension_std', 'orig_Critical_Age_Hypertension_skew', 'orig_Critical_Age_Hypertension_count', 'orig_Age_50_Plus_mean', 'orig_Age_50_Plus_median', 'orig_Age_50_Plus_std', 'orig_Age_50_Plus_skew', 'orig_Age_50_Plus_count', 'orig_Age50_Risk_Interaction_mean', 'orig_Age50_Risk_Interaction_median', 'orig_Age50_Risk_Interaction_std', 'orig_Age50_Risk_Interaction_skew', 'orig_Age50_Risk_Interaction_count', 'orig_Sex_Risk_Interaction_mean', 'orig_Sex_Risk_Interaction_median', 'orig_Sex_Risk_Interaction_std', 'orig_Sex_Risk_Interaction_skew', 'orig_Sex_Risk_Interaction_count', 'dist_to_real_patient', 'Real_Patient_Cluster']
# ✅ Fold 4 finished on cuda:1. AUC: 0.95543
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# ========================================
# Mean AUC: 0.95543
# ========================================
# CPU times: user 1min 4s, sys: 3.48 s, total: 1min 7s
# Wall time: 25min 38s

# %%
from sklearn.calibration import CalibrationDisplay

plt.figure(figsize=(12, 5)) 
plt.suptitle('RealMLP', fontsize=20) 

ax1 = plt.subplot(1, 2, 1)
CalibrationDisplay.from_predictions(y, oof_preds, n_bins=100, strategy='quantile', ax=ax1)
ax1.set_title('Calibration Curve')

ax2 = plt.subplot(1, 2, 2)
ax2.hist(oof_preds, bins=100, edgecolor='black', alpha=0.7)
ax2.set_title('Prediction Distribution (Histogram)')
ax2.set_xlabel('Predicted Probability')
ax2.set_ylabel('Count')

plt.tight_layout(rect=[0, 0.03, 1, 0.95]) 
plt.show()

# %% [markdown]
# # Evaluation and Submission

# %%
total_oof_score = roc_auc_score(y, oof_preds) 

print("\n" + "="*40)
print(f"Overall OOF ROC-AUC: {total_oof_score:.5f}")
print(f"Mean Fold Score: {np.mean(fold_scores):.5f} (+/- {np.std(fold_scores):.5f})")
print("="*40)

pd.DataFrame({'id': train['id'], 'Heart Disease_prob': oof_preds}).to_csv('oof.csv', index=False)

submission = pd.DataFrame({'id': test['id'], 'Heart Disease': test_preds})
submission.to_csv('submission.csv', index=False)
submission.head()
# Out:
# ========================================
# Overall OOF ROC-AUC: 0.95539
# Mean Fold Score: 0.95543 (+/- 0.00054)
# ========================================
#        id  Heart Disease
# 0  630000       0.954781
# 1  630001       0.007992
# 2  630002       0.990007
# 3  630003       0.005690
# 4  630004       0.222662

# %% [markdown]
# # Baseline
# 现在考虑了original的特征并加入了train作为了特征量
# 使用了frequency版的mlp
#
#
#
# 1. "Five risk factors account for approximately 50% of the global burden of cardiovascular disease. How the presence or absence of classic risk factors affects lifetime estimates of cardiovascular disease and death from any cause remains unclear."
#
# "Lifetime risk of cardiovascular disease and death from any cause was estimated up to 90 years of age according to the presence or absence of arterial hypertension, hyperlipidemia, underweight and overweight or obesity, diabetes, and smoking at 50 years of age. Differences in life span (in terms of additional life-years free of cardiovascular disease or death from any cause) according to the presence or absence of these risk factors were also estimated."
#
# "The lifetime risk of cardiovascular disease was 24% (95% confidence interval [CI], 21 to 30) among women and 38% (95% CI, 30 to 45) among men for whom all five risk factors were present. In the comparison between participants with none of the risk factors and those with all the risk factors, the estimated number of additional life-years free of cardiovascular disease was 13.3 (95% CI, 11.2 to 15.7) for women and 10.6 (95% CI, 9.2 to 12.9) for men; the estimated number of additional life-years free of death was 14.5 (95% CI, 9.1 to 15.3) for women and 11.8 (95% CI, 10.1 to 13.6) for men. As compared with no changes in the presence of all risk factors, modification of hypertension at an age of 55 to less than 60 years was associated with the most additional life-years free of cardiovascular disease, and modification of smoking at an age of 55 to less than 60 years was associated with the most additional life-years free of death."
#
# "The absence of five classic risk factors at 50 years of age was associated with more than a decade greater life expectancy than the presence of all five risk factors, in both sexes. Persons who modified hypertension and smoking in midlife had the most additional life-years free of cardiovascular disease and death from any cause, respectively." 基于这个考虑扩张特征量
#
# 2. 用lgbm+mlp的混合模型
# 3. 现在age,BP, Cholesterol都label embedding了，再考虑一下是不是应该保留数值呢
# 4. 混合模型时考虑核心 trick：裁判模型不仅看 MLP 和 CatBoost 的预测值，还看原始数据的特征（Age, Sex...）。
#
# 原理：有时候，MLP 在某些特定年龄段（比如 60-70 岁）特别准，而 CatBoost 在年轻人中特别准。如果把原始特征（Age）也喂给裁判模型，裁判就能学会：“哦，这是一个 65 岁的病人，那我要多听 MLP 的意见；如果是个年轻人，我就听 CatBoost 的。”
#
# Broccoli Beef 的代码演示了用 StackingClassifier(..., passthrough=True) 实现了这一点，并获得了分数的微弱提升。
